# %%
import pandas as pd, json, numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from pygeocoder import Geocoder
apik='AIzaSyDybC2OroTE_XDJTuxjKruxFpby5VDhEGk'

# %%
dfs=pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_by_national_capital,_largest_and_second-largest_cities')

# %%
dfs[1][210:230]
# Out:
#                                                      0  \
# 210                                           Slovakia
# 211                                           Slovenia
# 212                                    Solomon Islands
# 213                                            Somalia
# 214                                       South Africa
# 215                                       Johannesburg
# 216  South Georgia and the South Sandwich Islands (UK)
# 217                            South Ossetia (Georgia)
# 218                                        South Sudan
# 219                                              Spain
# 220                                          Sri Lanka
# 221                                              Kandy
# 222                                              Sudan
# 223                                           Khartoum
# 224                                           Suriname
# 225                    Svalbard and Jan Mayen (Norway)
# 226                                          Swaziland
# 227                                             Sweden
# 228                                        Switzerland
# 229                                              Syria
#
#                              1                  2                       3  \
# 210                 Bratislava             Košice                   [197]
# 211                  Ljubljana            Maribor                   [198]
# 212                    Honiara               Gizo                   [199]
# 213                  Mogadishu           Hargeisa                     NaN
# 214                   Pretoria  Cape Town[Note 4]                  Durban
# 215          Cape Town[Note 4]                NaN                     NaN
# 216          King Edward Point          Grytviken                   [202]
# 217                 Tskhinvali          Akhalgori                     NaN
# 218                       Juba                Yei                     NaN
# 219                     Madrid          Barcelona                   [203]
# 220  Sri Jayawardenepura Kotte            Colombo  Dehiwala-Mount Lavinia
# 221                        NaN                NaN                     NaN
# 222                   Khartoum           Omdurman                Khartoum
# 223                 Port Sudan                NaN                     NaN
# 224                 Paramaribo           Lelydorp                   [208]
# 225               Longyearbyen        Barentsburg                   [209]
# 226                    Mbabane            Manzini                 Mbabane
# 227                  Stockholm         Gothenburg                   [211]
# 228                       Bern             Zürich                  Geneva
# 229                   Damascus             Aleppo                Damascus
#
#                4
# 210          NaN
# 211          NaN
# 212          NaN
# 213          NaN
# 214  [200] [201]
# 215          NaN
# 216          NaN
# 217          NaN
# 218          NaN
# 219          NaN
# 220  [204] [205]
# 221          NaN
# 222  [206] [207]
# 223          NaN
# 224          NaN
# 225          NaN
# 226        [210]
# 227          NaN
# 228        [212]
# 229  [213] [214]

# %%
def repl(s):
    return s.replace('[Note 1]','').replace('[Note 2]','').replace('[Note 3]','').replace('[Note 4]','').replace('[Note 5]','')

# %%
countries={}
country=''
for i in dfs[1][4:].T.iteritems():
    if ('nan' == repr(i[1][2])):
        countries[country]['cities'].append(repl(i[1][0]))
        if ('nan' != repr(i[1][1])):
            countries[country]['cities'].append(repl(i[1][1]))
    else:
        country=repl(i[1][0])
        if country not in countries:countries[country]={'capital':'','cities':[]}
        countries[country]['capital']=repl(i[1][1])
        countries[country]['cities'].append(repl(i[1][2]))
        if not (('[' in repr(i[1][3])) or ('nan' == repr(i[1][3]))):
            countries[country]['cities'].append(repl(i[1][3]))

# %%
for c in countries:
    countries[c]['cities']=list(set(countries[c]['cities']))

# %%
pd.DataFrame(countries).T.to_excel('capitals.xlsx')

# %%
coords={}
errors=[]

# %%
for embassy in countries:
    print embassy            
    for host in countries:
        if embassy!=host:
            s='Embassy of '+embassy+' in '+countries[host]['capital']+', '+host
            #for consulate in countries[host]['cities']:
            #    print 'Consulate of '+embassy+' in '+consulate+', '+host
ong (China) Moldova Morocco Guinea-Bissau Switzerland Grenada Korea, North Iraq Estonia Kosovo Mexico Korea, South Uzbekistan Tunisia Djibouti Antigua and Barbuda Colombia Taiwan Barbados Virgin Islands, United States (US) Italy Bhutan Sudan Nepal Suriname Venezuela Thailand Israel Iceland Senegal Papua New Guinea Trinidad and Tobago Germany Vanuatu Kazakhstan Kyrgyzstan Macedonia Sri Lanka Latvia Guyana Honduras Myanmar Equatorial Guinea Egypt Nicaragua United Kingdom Puerto Rico (US) Greece Namibia Comoros Argentina
# Canada United States of America Ethiopia Bolivia Cameroon Bermuda (UK) Saudi Arabia Japan Cape Verde Slovenia Guatemala Kuwait Maldives Isle of Man (UK) Tanzania Vietnam Monaco Tonga New Zealand Saint Helena (UK) Andorra Congo, Republic of the United Arab Emirates Uruguay India Azerbaijan Kenya Tajikistan China, People's Republic of Turkey Afghanistan Bangladesh Mauritania Palau San Marino Mongolia France Rwanda Peru Laos Norway French Polynesia (France) Federated States of Micronesia Western Sahara Cuba Montenegro Armenia Dominican Republic Ukraine Indonesia Finland Australia Cayman Islands (UK) Russia Bulgaria Romania Angola South Africa Sweden Qatar Malaysia Austria Saint Martin (France) Mozambique Hungary Niger Brazil Netherlands Tokelau (New Zealand) Panama Congo, Democratic Republic of the Costa Rica Ireland Pakistan Anguilla (UK) Nigeria Ecuador Aruba (Netherlands) Brunei Guam (US) Iran Algeria El Salvador Czech Republic Chile Belgium Haiti Saint Lucia Spain Hong Kong (China) Denmark Philippines Cook Islands (New Zealand) Morocco Falkland Islands (UK) Switzerland State of Palestine Iraq Portugal Kosovo Mexico Lebanon Korea, South Tunisia Djibouti Guernsey (UK) Colombia Taiwan Montserrat (UK) Barbados Madagascar Italy Cocos (Keeling) Islands (Australia) Suriname Venezuela Thailand Sint Maarten (Netherlands) Senegal Papua New Guinea Germany Vanuatu Niue (New Zealand) Poland Kyrgyzstan Sri Lanka South Sudan Guyana Syria American Samoa (US) Honduras Myanmar Equatorial Guinea Egypt Nicaragua Serbia Botswana United Kingdom Puerto Rico (US) Greece Paraguay Namibia Greenland (Denmark) Bolivia
# Canada East Timor Turkmenistan United States of America Lithuania Cambodia Saint Kitts and Nevis Ethiopia Swaziland Argentina Cameroon Bermuda (UK)
# ---------------------------------------------------------------------------
# GeocoderError                             Traceback (most recent call last)
# <ipython-input-107-b66afe48de9f> in <module>()
#      14                     if e[0]=='ZERO_RESULTS':
#      15                         errors.append([host,embassy])
# ---> 16                     else: raise e
#
# GeocoderError: Error OVER_QUERY_LIMIT
# Query: https://maps.google.com/maps/api/geocode/json?key=AIzaSyDybC2OroTE_XDJTuxjKruxFpby5VDhEGk&language=&region=&bounds=&components=&address=Embassy+of+Bolivia+in+Accra%2C+Ghana&sensor=false

# %%
import json

# %%
'https://embassy-finder.com/'

# %%
coords
# Out:
# {u'Abkhazia (Georgia)': {u'Canada': <pygeolib.GeocoderResult at 0x14734da0>},
#  u'Afghanistan': {u'Canada': <pygeolib.GeocoderResult at 0x141b1160>},
#  u'Albania': {u'Canada': <pygeolib.GeocoderResult at 0x141b1d30>},
#  u'Algeria': {u'Canada': <pygeolib.GeocoderResult at 0x13ebf0b8>},
#  u'Andorra': {u'Canada': <pygeolib.GeocoderResult at 0x141add30>},
#  u'Angola': {u'Canada': <pygeolib.GeocoderResult at 0x1413cac8>},
#  u'Anguilla (UK)': {u'Canada': <pygeolib.GeocoderResult at 0x13eb7278>},
#  u'Argentina': {u'Canada': <pygeolib.GeocoderResult at 0x14734b70>},
#  u'Armenia': {u'Canada': <pygeolib.GeocoderResult at 0x1437bac8>},
#  u'Aruba (Netherlands)': {u'Canada': <pygeolib.GeocoderResult at 0x13eb7ef0>},
#  u'Australia': {u'Canada': <pygeolib.GeocoderResult at 0x1402a2b0>},
#  u'Austria': {u'Canada': <pygeolib.GeocoderResult at 0x13eb7080>},
#  u'Azerbaijan': {u'Canada': <pygeolib.GeocoderResult at 0x141add68>},
#  u'Bahamas': {u'Canada': <pygeolib.GeocoderResult at 0x13eb7ba8>},
#  u'Bahrain': {u'Canada': <pygeolib.GeocoderResult at 0x1402a668>},
#  u'Bangladesh': {u'Canada': <pygeolib.GeocoderResult at 0x1402a5c0>},
#  u'Belarus': {u'Canada': <pygeolib.GeocoderResult at 0x13ebfcc0>},
#  u'Belgium': {u'Canada': <pygeolib.GeocoderResult at 0x14006470>},
#  u'Belize': {},
#  u'Benin': {u'Canada': <pygeolib.GeocoderResult at 0x1402a470>},
#  u'Bermuda (UK)': {u'Canada': <pygeolib.GeocoderResult at 0x1437c128>},
#  u'Bolivia': {u'Canada': <pygeolib.GeocoderResult at 0x1476d588>},
#  u'Bosnia and Herzegovina': {u'Canada': <pygeolib.GeocoderResult at 0x1435c0b8>},
#  u'Brazil': {u'Canada': <pygeolib.GeocoderResult at 0x13eb7a90>},
#  u'Brunei': {u'Canada': <pygeolib.GeocoderResult at 0x1413cef0>},
#  u'Bulgaria': {u'Canada': <pygeolib.GeocoderResult at 0x13eb7588>},
#  u'Burkina Faso': {u'Canada': <pygeolib.GeocoderResult at 0x1437b6a0>},
#  u'Cambodia': {u'Canada': <pygeolib.GeocoderResult at 0x1437ca90>},
#  u'Cameroon': {u'Canada': <pygeolib.GeocoderResult at 0x14734d68>},
#  u'Cape Verde': {u'Canada': <pygeolib.GeocoderResult at 0x1437b780>},
#  u'Cayman Islands (UK)': {u'Canada': <pygeolib.GeocoderResult at 0x1402a7f0>},
#  u'Central African Republic': {u'Canada': <pygeolib.GeocoderResult at 0x14006358>},
#  u'Chad': {u'Canada': <pygeolib.GeocoderResult at 0x1402a630>},
#  u'Chile': {u'Canada': <pygeolib.GeocoderResult at 0x13eb70f0>},
#  u"China, People's Republic of": {u'Canada': <pygeolib.GeocoderResult at 0x141b1d68>},
#  u'Christmas Island (Australia)': {u'Canada': <pygeolib.GeocoderResult at 0x141b1c50>},
#  u'Congo, Democratic Republic of the': {u'Canada': <pygeolib.GeocoderResult at 0x1413cd30>},
#  u'Congo, Republic of the': {u'Canada': <pygeolib.GeocoderResult at 0x1402a240>},
#  u'Cook Islands (New Zealand)': {u'Canada': <pygeolib.GeocoderResult at 0x145da4a8>},
#  u'Costa Rica': {u'Canada': <pygeolib.GeocoderResult at 0x13eb79b0>},
#  u'Croatia': {u'Canada': <pygeolib.GeocoderResult at 0x13ebf208>},
#  u'Cuba': {u'Canada': <pygeolib.GeocoderResult at 0x14734ac8>},
#  u'Cura\xe7ao (Netherlands)': {},
#  u'Czech Republic': {u'Canada': <pygeolib.GeocoderResult at 0x1413c898>},
#  u'Denmark': {u'Canada': <pygeolib.GeocoderResult at 0x1402ab70>},
#  u'Dominica': {u'Canada': <pygeolib.GeocoderResult at 0x141b1208>},
#  u'Dominican Republic': {u'Canada': <pygeolib.GeocoderResult at 0x141b1400>},
#  u'East Timor': {},
#  u'Ecuador': {u'Canada': <pygeolib.GeocoderResult at 0x13ebf5f8>},
#  u'El Salvador': {u'Canada': <pygeolib.GeocoderResult at 0x1402ab38>},
#  u'Ethiopia': {u'Canada': <pygeolib.GeocoderResult at 0x14734be0>},
#  u'Falkland Islands (UK)': {},
#  u'Federated States of Micronesia': {},
#  u'Fiji': {u'Canada': <pygeolib.GeocoderResult at 0x1402a828>},
#  u'Finland': {u'Canada': <pygeolib.GeocoderResult at 0x1402a208>},
#  u'France': {u'Canada': <pygeolib.GeocoderResult at 0x1437b390>},
#  u'French Guiana (France)': {},
#  u'French Polynesia (France)': {u'Canada': <pygeolib.GeocoderResult at 0x1476d9b0>},
#  u'Gabon': {u'Canada': <pygeolib.GeocoderResult at 0x1437b128>},
#  u'Georgia': {u'Canada': <pygeolib.GeocoderResult at 0x141b13c8>},
#  u'Ghana': {u'Canada': <pygeolib.GeocoderResult at 0x14734eb8>},
#  u'Grenada': {u'Canada': <pygeolib.GeocoderResult at 0x13ebf080>},
#  u'Guam (US)': {u'Canada': <pygeolib.GeocoderResult at 0x145da080>},
#  u'Guatemala': {u'Canada': <pygeolib.GeocoderResult at 0x1437bdd8>},
#  u'Guinea': {u'Canada': <pygeolib.GeocoderResult at 0x141b1668>},
#  u'Guinea-Bissau': {},
#  u'Haiti': {u'Canada': <pygeolib.GeocoderResult at 0x145da550>},
#  u'Hong Kong (China)': {u'Canada': <pygeolib.GeocoderResult at 0x13ebf1d0>},
#  u'Hungary': {u'Canada': <pygeolib.GeocoderResult at 0x13eb7b00>},
#  u'India': {u'Canada': <pygeolib.GeocoderResult at 0x1402a898>},
#  u'Indonesia': {u'Canada': <pygeolib.GeocoderResult at 0x14006550>},
#  u'Iran': {u'Canada': <pygeolib.GeocoderResult at 0x1413c0f0>},
#  u'Ireland': {u'Canada': <pygeolib.GeocoderResult at 0x1413c400>},
#  u'Isle of Man (UK)': {u'Canada': <pygeolib.GeocoderResult at 0x141b12b0>},
#  u'Jamaica': {u'Canada': <pygeolib.GeocoderResult at 0x1437b278>},
#  u'Japan': {u'Canada': <pygeolib.GeocoderResult at 0x1435cbe0>},
#  u'Jersey (UK)': {u'Canada': <pygeolib.GeocoderResult at 0x13ffcb38>},
#  u'Jordan': {u'Canada': <pygeolib.GeocoderResult at 0x1435c4e0>},
#  u'Kenya': {u'Canada': <pygeolib.GeocoderResult at 0x1402a160>},
#  u'Kiribati': {},
#  u'Korea, North': {},
#  u'Kuwait': {u'Canada': <pygeolib.GeocoderResult at 0x1437ba20>},
#  u'Laos': {u'Canada': <pygeolib.GeocoderResult at 0x14006240>},
#  u'Lesotho': {u'Canada': <pygeolib.GeocoderResult at 0x1402ae10>},
#  u'Liberia': {u'Canada': <pygeolib.GeocoderResult at 0x141b1a20>},
#  u'Libya': {u'Canada': <pygeolib.GeocoderResult at 0x1402a860>},
#  u'Liechtenstein': {u'Canada': <pygeolib.GeocoderResult at 0x1402af60>},
#  u'Lithuania': {u'Canada': <pygeolib.GeocoderResult at 0x1437c668>},
#  u'Luxembourg': {u'Canada': <pygeolib.GeocoderResult at 0x1413c2e8>},
#  u'Malaysia': {u'Canada': <pygeolib.GeocoderResult at 0x1413cf28>},
#  u'Maldives': {u'Canada': <pygeolib.GeocoderResult at 0x1437b160>},
#  u'Mali': {u'Canada': <pygeolib.GeocoderResult at 0x13eb7f28>},
#  u'Marshall Islands': {},
#  u'Mauritania': {},
#  u'Mauritius': {u'Canada': <pygeolib.GeocoderResult at 0x1413c4a8>},
#  u'Mayotte (France)': {},
#  u'Moldova': {u'Canada': <pygeolib.GeocoderResult at 0x141b1cc0>},
#  u'Monaco': {u'Canada': <pygeolib.GeocoderResult at 0x1437b940>},
#  u'Mongolia': {u'Canada': <pygeolib.GeocoderResult at 0x1437cb38>},
#  u'Montenegro': {},
#  u'Morocco': {u'Canada': <pygeolib.GeocoderResult at 0x145da3c8>},
#  u'Mozambique': {u'Canada': <pygeolib.GeocoderResult at 0x1413c080>},
#  u'Nagorno-Karabakh (Azerbaijan)': {u'Canada': <pygeolib.GeocoderResult at 0x145daf60>},
#  u'Nauru': {},
#  u'Netherlands': {u'Canada': <pygeolib.GeocoderResult at 0x141b1710>},
#  u'New Zealand': {u'Canada': <pygeolib.GeocoderResult at 0x1435c908>},
#  u'Niger': {},
#  u'Nigeria': {u'Canada': <pygeolib.GeocoderResult at 0x1413c7f0>},
#  u'Norfolk Island (Australia)': {u'Canada': <pygeolib.GeocoderResult at 0x1413c8d0>},
#  u'Northern Mariana Islands (US)': {u'Canada': <pygeolib.GeocoderResult at 0x1402a9b0>},
#  u'Norway': {u'Canada': <pygeolib.GeocoderResult at 0x1435c940>},
#  u'Oman': {u'Canada': <pygeolib.GeocoderResult at 0x141b1ba8>},
#  u'Pakistan': {u'Canada': <pygeolib.GeocoderResult at 0x13ebfe80>},
#  u'Palau': {},
#  u'Panama': {u'Canada': <pygeolib.GeocoderResult at 0x13eb7470>},
#  u'Peru': {u'Canada': <pygeolib.GeocoderResult at 0x1437b438>},
#  u'Philippines': {u'Canada': <pygeolib.GeocoderResult at 0x13ebf0f0>},
#  u'Qatar': {u'Canada': <pygeolib.GeocoderResult at 0x13eb7a58>},
#  u'Romania': {u'Canada': <pygeolib.GeocoderResult at 0x141b1be0>},
#  u'Russia': {u'Canada': <pygeolib.GeocoderResult at 0x141b1e80>},
#  u'Rwanda': {u'Canada': <pygeolib.GeocoderResult at 0x1402a320>},
#  u'Saint Barth\xe9lemy (France)': {u'Canada': <pygeolib.GeocoderResult at 0x1413c908>},
#  u'Saint Helena (UK)': {u'Canada': <pygeolib.GeocoderResult at 0x141b1f60>},
#  u'Saint Kitts and Nevis': {u'Canada': <pygeolib.GeocoderResult at 0x1437c748>},
#  u'Saint Lucia': {u'Canada': <pygeolib.GeocoderResult at 0x14006860>},
#  u'Saint Martin (France)': {u'Canada': <pygeolib.GeocoderResult at 0x13eb7d30>},
#  u'Saint Pierre and Miquelon (France)': {u'Canada': <pygeolib.GeocoderResult at 0x14006908>},
#  u'Saint Vincent and the Grenadines': {u'Canada': <pygeolib.GeocoderResult at 0x141adda0>},
#  u'Samoa': {u'Canada': <pygeolib.GeocoderResult at 0x141adc88>},
#  u'San Marino': {u'Canada': <pygeolib.GeocoderResult at 0x141adfd0>},
#  u'Saudi Arabia': {u'Canada': <pygeolib.GeocoderResult at 0x1437c940>},
#  u'Seychelles': {},
#  u'Slovakia': {u'Canada': <pygeolib.GeocoderResult at 0x1437beb8>},
#  u'Slovenia': {u'Canada': <pygeolib.GeocoderResult at 0x1476d2b0>},
#  u'Solomon Islands': {u'Canada': <pygeolib.GeocoderResult at 0x1402a518>},
#  u'Somalia': {u'Canada': <pygeolib.GeocoderResult at 0x1402ac88>},
#  u'South Africa': {u'Canada': <pygeolib.GeocoderResult at 0x1413c048>},
#  u'South Ossetia (Georgia)': {u'Canada': <pygeolib.GeocoderResult at 0x140069b0>},
#  u'Spain': {u'Canada': <pygeolib.GeocoderResult at 0x1413cdd8>},
#  u'State of Palestine': {},
#  u'Svalbard and Jan Mayen (Norway)': {u'Canada': <pygeolib.GeocoderResult at 0x1435c470>},
#  u'Swaziland': {},
#  u'Sweden': {u'Canada': <pygeolib.GeocoderResult at 0x141adeb8>},
#  u'Switzerland': {u'Canada': <pygeolib.GeocoderResult at 0x13eb7828>},
#  u'Tajikistan': {u'Canada': <pygeolib.GeocoderResult at 0x141b1b70>},
#  u'Tanzania': {u'Canada': <pygeolib.GeocoderResult at 0x1437b198>},
#  u'Togo': {u'Canada': <pygeolib.GeocoderResult at 0x1413c2b0>},
#  u'Tokelau (New Zealand)': {u'Canada': <pygeolib.GeocoderResult at 0x13eb7e48>},
#  u'Tonga': {},
#  u'Transnistria (Moldova)': {},
#  u'Turkey': {u'Canada': <pygeolib.GeocoderResult at 0x1402a128>},
#  u'Turkmenistan': {},
#  u'Turks and Caicos Islands (UK)': {},
#  u'Tuvalu': {u'Canada': <pygeolib.GeocoderResult at 0x13ebf320>},
#  u'Uganda': {u'Canada': <pygeolib.GeocoderResult at 0x13eb7e10>},
#  u'Ukraine': {u'Canada': <pygeolib.GeocoderResult at 0x140064a8>},
#  u'United Arab Emirates': {u'Canada': <pygeolib.GeocoderResult at 0x141ade48>},
#  u'United States of America': {u'Canada': <pygeolib.GeocoderResult at 0x140a4da0>},
#  u'Uruguay': {u'Canada': <pygeolib.GeocoderResult at 0x141b1358>},
#  u'Vietnam': {u'Canada': <pygeolib.GeocoderResult at 0x141b10f0>},
#  u'Wallis and Futuna (France)': {u'Canada': <pygeolib.GeocoderResult at 0x1437b048>},
#  u'Western Sahara': {u'Canada': <pygeolib.GeocoderResult at 0x141b16a0>},
#  u'Yemen': {},
#  u'Zimbabwe': {u'Canada': <pygeolib.GeocoderResult at 0x1435c668>},
#  u'\xc5land Islands (Finland)': {u'Canada': <pygeolib.GeocoderResult at 0x141b1278>}}

# %%
file('data.json','w').write(json.dumps(coords))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-dd92849c3023> in <module>()
# ----> 1 file('data.json','w').write(json.dumps(coords))
#
# C:\Anaconda2\lib\json\__init__.pyc in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, encoding, default, sort_keys, **kw)
#     242         cls is None and indent is None and separators is None and
#     243         encoding == 'utf-8' and default is None and not sort_keys and not kw):
# --> 244         return _default_encoder.encode(obj)
#     245     if cls is None:
#     246         cls = JSONEncoder
#
# C:\Anaconda2\lib\json\encoder.pyc in encode(self, o)
#     205         # exceptions aren't as detailed.  The list call should be roughly
#     206         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 207         chunks = self.iterencode(o, _one_shot=True)
#     208         if not isinstance(chunks, (list, tuple)):
#     209             chunks = list(chunks)
#
# C:\Anaconda2\lib\json\encoder.pyc in iterencode(self, o, _one_shot)
#     268                 self.key_separator, self.item_separator, self.sort_keys,
#     269                 self.skipkeys, _one_shot)
# --> 270         return _iterencode(o, 0)
#     271
#     272 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# C:\Anaconda2\lib\json\encoder.pyc in default(self, o)
#     182
#     183         """
# --> 184         raise TypeError(repr(o) + " is not JSON serializable")
#     185
#     186     def encode(self, o):
#
# TypeError: <pygeolib.GeocoderResult object at 0x000000001437C668> is not JSON serializable
