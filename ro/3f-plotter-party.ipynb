# %%
import pandas as pd, numpy as np, json, os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.style.use('seaborn-whitegrid')

# %%
#!pip install d3IpyPlus
from d3IpyPlus import ScatterPlot, LinePlot, BarPlot, StackedArea

# %%
#!pip install pyecharts

# %%
m=json.loads(open('ignore/member_timelines.json','r').read())
members=json.loads(open('ignore/member_simple.json','r').read())

# %%
d=pd.DataFrame(members['deaths'],index=['v']).T

# %%
d['v']=' †'

# %%
s=pd.DataFrame(members['s2'],index=['s']).T
s=s.join(d)
s['v']=s['v'].fillna('')
s['s']=s['s']+s['v']
s=s[['s']]
s['w']=s['s'].str.split(' ').str[0].str[0]+s['s'].str.split(' ').str[-1].str[0]

# %%
szd_color='#E91C62'

# %%
pcolors=json.loads(open('json/pcolors.json','r').read())

# %%
g=pd.DataFrame(members['megye'],index=['Megye ']).T
g.head()
# Out:
#                                          Megye
# Alexandrescu Emil Lucian | 1937-11-19   🇷🇴 Iași
# Dobritoiu Teodoru | 1954-06-14         🇷🇴 Galac
# Stef Mircea-Ioan | 1930-11-07           🇷🇴 Iași
# Barbat Vasile | 1937-10-06             🇷🇴 Temes
# Dumitrescu Alexandru | Ismeretlen      🇷🇴 Buzău

# %%
data={}
attention={}
for k,i in enumerate(m):
    if k%1000==0: print(k/len(m)*100,'%')
    if i['Típus']=='Párt':
        if i['Csoportok'] not in data:data[i['Csoportok']]={'start':pd.to_datetime('2030'),'end':pd.to_datetime('1980')}
        start=pd.to_datetime(i['start'])
        end=pd.to_datetime(i['end'])
        data[i['Csoportok']]['start']=min(data[i['Csoportok']]['start'],start)
        data[i['Csoportok']]['end']=max(data[i['Csoportok']]['end'],end)
# Out:
# 0.0 %
# 3.3029462280354074 %
# 6.605892456070815 %
# 9.908838684106223 %
# 13.21178491214163 %
# 16.514731140177037 %
# 19.817677368212447 %
# 23.120623596247853 %
# 26.42356982428326 %
# 29.72651605231867 %
# 33.029462280354075 %
# 36.332408508389484 %
# 39.635354736424894 %
# 42.938300964460296 %
# 46.241247192495706 %
# 49.544193420531116 %
# 52.84713964856652 %
# 56.15008587660193 %
# 59.45303210463734 %
# 62.75597833267275 %
# 66.05892456070815 %
# 69.36187078874356 %
# 72.66481701677897 %
# 75.96776324481438 %
# 79.27070947284979 %
# 82.57365570088518 %
# 85.87660192892059 %
# 89.179548156956 %
# 92.48249438499141 %
# 95.78544061302682 %
# 99.08838684106223 %

# %%
part_timelines=pd.DataFrame(data).T
part_timelines.index.name='id'

# %%
part_timelines['start']=part_timelines['start'].astype(str).str[:10]
part_timelines['end']=part_timelines['end'].astype(str).str[:10]

# %%
p=part_timelines.reset_index()[['id']]
p['Color']=p['id'].str.split(' ').str[1].str.strip()
p['Part']=p['id'].str.split('-').str[0].str.strip()
p=p.join(pd.DataFrame(pcolors,index=['cvalue']).T,on='Color').fillna('grey')

# %%
part_timelines=part_timelines.join(p.set_index('id').drop_duplicates())

# %%
logos={'🕊️':'ALDE', '🌹':'PSD', '📐':'PNL', '🔶':'PD', '⚛️':'PP-DD', '👤':'Független', '⚪️':'FSN',
       '✳️':'PNTCD', '🔱':'PRM', '🌷':'RMDSZ', '🍀':'ECO', '🍏':'PMP',
       '🔷':'USR', '🦅':'UNPR', '🔘':'Más'}

# %%
part_timelines['logo']=part_timelines['Part'].str.split(' ').str[0]

# %%
part_timelines['group']=[logos[i] for i in part_timelines['logo'].values]
part_timelines['label']=[i+' '+logos[i] for i in part_timelines['logo'].values]

# %%
part_timelines=list(part_timelines.reset_index().T.to_dict().values())

# %%
open('json/part_timelines.json','w').write(json.dumps(part_timelines))
# Out:
# 9883

# %%
part_timelines
# Out:
# [{'id': '🕊️ PC - Partidul Conservator',
#   'end': '2016-12-21',
#   'start': '2004-12-19',
#   'Color': 'PC',
#   'Part': '🕊️ PC',
#   'cvalue': '#96c2f2',
#   'logo': '🕊️',
#   'group': 'ALDE',
#   'label': '🕊️ ALDE'},
#  {'id': '🕊️ PUR-SL - Partidul Umanist din România',
#   'end': '2005-05-01',
#   'start': '2000-12-15',
#   'Color': 'PUR-SL',
#   'Part': '🕊️ PUR',
#   'cvalue': 'grey',
#   'logo': '🕊️',
#   'group': 'ALDE',
#   'label': '🕊️ ALDE'},
#  {'id': '🌹 PSD - Partidul Social Democrat',
#   'end': '2019-07-01',
#   'start': '2000-12-15',
#   'Color': 'PSD',
#   'Part': '🌹 PSD',
#   'cvalue': '#dc2c24',
#   'logo': '🌹',
#   'group': 'PSD',
#   'label': '🌹 PSD'},
#  {'id': '🕊️ PUNR - Partidul Unităţii Naţionale Române',
#   'end': '2000-11-30',
#   'start': '1990-06-19',
#   'Color': 'PUNR',
#   'Part': '🕊️ PUNR',
#   'cvalue': 'grey',
#   'logo': '🕊️',
#   'group': 'ALDE',
#   'label': '🕊️ ALDE'},
#  {'id': '📐 PNL - Partidul Naţional Liberal',
#   'end': '2019-07-01',
#   'start': '1990-06-19',
#   'Color': 'PNL',
#   'Part': '📐 PNL',
#   'cvalue': '#f4d42c',
#   'logo': '📐',
#   'group': 'PNL',
#   'label': '📐 PNL'},
#  {'id': '🔶 PDL - Partidul Democrat Liberal',
#   'end': '2016-12-21',
#   'start': '2004-12-19',
#   'Color': 'PDL',
#   'Part': '🔶 PDL',
#   'cvalue': 'darkOrange',
#   'logo': '🔶',
#   'group': 'PD',
#   'label': '🔶 PD'},
#  {'id': '⚛️ PP-DD - Partidul Poporului Dan Diaconescu',
#   'end': '2016-12-21',
#   'start': '2012-12-20',
#   'Color': 'PP-DD',
#   'Part': '⚛️ PP',
#   'cvalue': '#9966cc',
#   'logo': '⚛️',
#   'group': 'PP-DD',
#   'label': '⚛️ PP-DD'},
#  {'id': '👤 Independent - Independent',
#   'end': '2019-07-01',
#   'start': '1990-06-19',
#   'Color': 'Independent',
#   'Part': '👤 Independent',
#   'cvalue': '#444',
#   'logo': '👤',
#   'group': 'Független',
#   'label': '👤 Független'},
#  {'id': '⚪️ FSN - Frontul Salvării Naţionale',
#   'end': '1996-11-22',
#   'start': '1990-06-19',
#   'Color': 'FSN',
#   'Part': '⚪️ FSN',
#   'cvalue': 'grey',
#   'logo': '⚪️',
#   'group': 'FSN',
#   'label': '⚪️ FSN'},
#  {'id': '🌹 PDSR - Partidul Democraţiei Sociale din România',
#   'end': '2004-11-30',
#   'start': '1992-10-28',
#   'Color': 'PDSR',
#   'Part': '🌹 PDSR',
#   'cvalue': '#dc2c24',
#   'logo': '🌹',
#   'group': 'PSD',
#   'label': '🌹 PSD'},
#  {'id': '🔶 PD - Partidul Democrat',
#   'end': '2008-12-13',
#   'start': '1992-10-28',
#   'Color': 'PD',
#   'Part': '🔶 PD',
#   'cvalue': 'darkOrange',
#   'logo': '🔶',
#   'group': 'PD',
#   'label': '🔶 PD'},
#  {'id': '🌹 PSDR - Partidul Social Democrat Român',
#   'end': '2001-06-01',
#   'start': '1990-06-19',
#   'Color': 'PSDR',
#   'Part': '🌹 PSDR',
#   'cvalue': '#dc2c24',
#   'logo': '🌹',
#   'group': 'PSD',
#   'label': '🌹 PSD'},
#  {'id': '📐 PAC - Partidul Alianţei Civice',
#   'end': '1996-11-22',
#   'start': '1992-10-28',
#   'Color': 'PAC',
#   'Part': '📐 PAC',
#   'cvalue': '#f4d42c',
#   'logo': '📐',
#   'group': 'PNL',
#   'label': '📐 PNL'},
#  {'id': '✳️ PNTCD - Partidul Naţional Ţărănesc Creştin Democrat',
#   'end': '2014-03-01',
#   'start': '1990-06-19',
#   'Color': 'PNTCD',
#   'Part': '✳️ PNTCD',
#   'cvalue': '#04843c',
#   'logo': '✳️',
#   'group': 'PNTCD',
#   'label': '✳️ PNTCD'},
#  {'id': '🔱 PRM - Partidul România Mare',
#   'end': '2009-09-01',
#   'start': '1992-10-28',
#   'Color': 'PRM',
#   'Part': '🔱 PRM',
#   'cvalue': '#0d5ca4',
#   'logo': '🔱',
#   'group': 'PRM',
#   'label': '🔱 PRM'},
#  {'id': '🌷 RMDSZ - Romániai Magyar Demokrata Szövetség',
#   'end': '2019-07-01',
#   'start': '1990-06-19',
#   'Color': 'RMDSZ',
#   'Part': '🌷 RMDSZ',
#   'cvalue': 'green',
#   'logo': '🌷',
#   'group': 'RMDSZ',
#   'label': '🌷 RMDSZ'},
#  {'id': '🍀 PER - Partidul Ecologist Român',
#   'end': '2000-11-30',
#   'start': '1990-06-19',
#   'Color': 'PER',
#   'Part': '🍀 PER',
#   'cvalue': '#69a54f',
#   'logo': '🍀',
#   'group': 'ECO',
#   'label': '🍀 ECO'},
#  {'id': "📐 PL'93 - Partidul Liberal",
#   'end': '1996-11-22',
#   'start': '1992-10-28',
#   'Color': "PL'93",
#   'Part': "📐 PL'93",
#   'cvalue': '#f4d42c',
#   'logo': '📐',
#   'group': 'PNL',
#   'label': '📐 PNL'},
#  {'id': '🕊️ ALDE - Partidul Alianţa Liberalilor şi Democraţilor',
#   'end': '2019-07-01',
#   'start': '2016-12-21',
#   'Color': 'ALDE',
#   'Part': '🕊️ ALDE',
#   'cvalue': '#046cab',
#   'logo': '🕊️',
#   'group': 'ALDE',
#   'label': '🕊️ ALDE'},
#  {'id': '⚪️ FDSN - Frontul Democrat al Salvarii Nationale',
#   'end': '1993-07-01',
#   'start': '1990-06-19',
#   'Color': 'FDSN',
#   'Part': '⚪️ FDSN',
#   'cvalue': 'grey',
#   'logo': '⚪️',
#   'group': 'FSN',
#   'label': '⚪️ FSN'},
#  {'id': '🍏 PMP - Partidul Mişcarea Populară',
#   'end': '2019-07-01',
#   'start': '2016-12-21',
#   'Color': 'PMP',
#   'Part': '🍏 PMP',
#   'cvalue': '#0484cc',
#   'logo': '🍏',
#   'group': 'PMP',
#   'label': '🍏 PMP'},
#  {'id': '🔷 USR - Uniunea Salvaţi România',
#   'end': '2019-07-01',
#   'start': '2016-12-21',
#   'Color': 'USR',
#   'Part': '🔷 USR',
#   'cvalue': '#04abe4',
#   'logo': '🔷',
#   'group': 'USR',
#   'label': '🔷 USR'},
#  {'id': '🦅 UNPR - Uniunea Naţională pentru Progresul României',
#   'end': '2016-12-21',
#   'start': '2012-12-20',
#   'Color': 'UNPR',
#   'Part': '🦅 UNPR',
#   'cvalue': '#a8190f',
#   'logo': '🦅',
#   'group': 'UNPR',
#   'label': '🦅 UNPR'},
#  {'id': '🍀 FER - Federaţia Ecologistă Română',
#   'end': '2000-11-30',
#   'start': '1996-11-27',
#   'Color': 'FER',
#   'Part': '🍀 FER',
#   'cvalue': '#69a54f',
#   'logo': '🍀',
#   'group': 'ECO',
#   'label': '🍀 ECO'},
#  {'id': '🍀 MER - Mişcarea Ecologistă din România',
#   'end': '1992-10-16',
#   'start': '1990-06-19',
#   'Color': 'MER',
#   'Part': '🍀 MER',
#   'cvalue': '#69a54f',
#   'logo': '🍀',
#   'group': 'ECO',
#   'label': '🍀 ECO'},
#  {'id': '🌹 PSM - Partidul Socialist al Muncii',
#   'end': '1996-11-22',
#   'start': '1992-10-28',
#   'Color': 'PSM',
#   'Part': '🌹 PSM',
#   'cvalue': '#dc2c24',
#   'logo': '🌹',
#   'group': 'PSD',
#   'label': '🌹 PSD'},
#  {'id': '📐 PNL-CD - Partidul Naţional Liberal',
#   'end': '2000-11-30',
#   'start': '1992-10-28',
#   'Color': 'PNL-CD',
#   'Part': '📐 PNL',
#   'cvalue': '#f4d42c',
#   'logo': '📐',
#   'group': 'PNL',
#   'label': '📐 PNL'},
#  {'id': '🔘 FC - Forţa Civică',
#   'end': '2016-12-21',
#   'start': '2012-12-20',
#   'Color': 'FC',
#   'Part': '🔘 FC',
#   'cvalue': '#1d7aad',
#   'logo': '🔘',
#   'group': 'Más',
#   'label': '🔘 Más'},
#  {'id': '🍀 PDAR - Partidul Democrat Agrar din România',
#   'end': '1996-11-22',
#   'start': '1990-06-19',
#   'Color': 'PDAR',
#   'Part': '🍀 PDAR',
#   'cvalue': '#69a54f',
#   'logo': '🍀',
#   'group': 'ECO',
#   'label': '🍀 ECO'},
#  {'id': '🔘 AUR - Alianţa pentru Unitatea Românilor',
#   'end': '1992-10-16',
#   'start': '1990-06-19',
#   'Color': 'AUR',
#   'Part': '🔘 AUR',
#   'cvalue': 'grey',
#   'logo': '🔘',
#   'group': 'Más',
#   'label': '🔘 Más'},
#  {'id': '🔘 PAR - Partidul Alternativa României',
#   'end': '2000-11-30',
#   'start': '1996-11-27',
#   'Color': 'PAR',
#   'Part': '🔘 PAR',
#   'cvalue': 'grey',
#   'logo': '🔘',
#   'group': 'Más',
#   'label': '🔘 Más'},
#  {'id': '📐 PNL-AT - Partidul Naţional Liberal',
#   'end': '1996-11-22',
#   'start': '1992-10-28',
#   'Color': 'PNL-AT',
#   'Part': '📐 PNL',
#   'cvalue': '#f4d42c',
#   'logo': '📐',
#   'group': 'PNL',
#   'label': '📐 PNL'},
#  {'id': '🔘 GDC - Gruparea Democratică de Centru',
#   'end': '1992-10-16',
#   'start': '1990-06-19',
#   'Color': 'GDC',
#   'Part': '🔘 GDC',
#   'cvalue': 'grey',
#   'logo': '🔘',
#   'group': 'Más',
#   'label': '🔘 Más'},
#  {'id': '🔘 PRNR - Partidul Reconstrucţiei Naţionale din România',
#   'end': '1992-10-16',
#   'start': '1990-06-19',
#   'Color': 'PRNR',
#   'Part': '🔘 PRNR',
#   'cvalue': 'grey',
#   'logo': '🔘',
#   'group': 'Más',
#   'label': '🔘 Más'},
#  {'id': '🔘 PLS - Partidul Liber Schimbist',
#   'end': '1992-10-16',
#   'start': '1990-06-19',
#   'Color': 'PLS',
#   'Part': '🔘 PLS',
#   'cvalue': 'grey',
#   'logo': '🔘',
#   'group': 'Más',
#   'label': '🔘 Más'},
#  {'id': '👤 Minorități - Minorități',
#   'end': '2019-07-01',
#   'start': '2016-12-21',
#   'Color': 'Minorități',
#   'Part': '👤 Minorități',
#   'cvalue': 'grey',
#   'logo': '👤',
#   'group': 'Független',
#   'label': '👤 Független'},
#  {'id': '🔘 ULB - Uniunea Liberală "Brătianu"',
#   'end': '1992-10-16',
#   'start': '1990-06-19',
#   'Color': 'ULB',
#   'Part': '🔘 ULB',
#   'cvalue': 'grey',
#   'logo': '🔘',
#   'group': 'Más',
#   'label': '🔘 Más'},
#  {'id': '🔘 PDM - Partidul Democrat al Muncii',
#   'end': '1992-10-16',
#   'start': '1990-06-19',
#   'Color': 'PDM',
#   'Part': '🔘 PDM',
#   'cvalue': 'grey',
#   'logo': '🔘',
#   'group': 'Más',
#   'label': '🔘 Más'},
#  {'id': '🔘 PTLDR - Partidul Tineretului Liber Democrat din România',
#   'end': '1992-10-16',
#   'start': '1990-06-19',
#   'Color': 'PTLDR',
#   'Part': '🔘 PTLDR',
#   'cvalue': 'grey',
#   'logo': '🔘',
#   'group': 'Más',
#   'label': '🔘 Más'}]
