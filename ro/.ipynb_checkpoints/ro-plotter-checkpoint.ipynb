# %%
import pandas as pd, numpy as np, json, os

# %%
base_url='http://www.cdep.ro'

# %%
os.chdir('C:/users/csala/Onedrive - Lancaster University/datarepo/influence/ro')

# %%
nmembers=json.loads(open('data/nmembers.json','r').read())

# %%
img=json.loads(open('data/img.json','r').read())

# %%
records=json.loads(open('data/records.json','r').read())

# %%
votes=json.loads(open('data/votes.json','r').read())

# %%
nvotes=json.loads(open('data/nvotes.json','r').read())

# %%
records[9]
# Out:
# {'votid': '318',
#  'vot': 'DA',
#  'grup': 'PSD',
#  'name': 'Timiş Ioan',
#  'camera': '2'}

# %%
votes[0]
# Out:
# {'votid': '318',
#  'descriere': 'Pl-x 596/2005',
#  'time': '06.02.2006 17:13',
#  'camera': '2'}

# %%
nvotes[0]
# Out:
# {'votid': '318',
#  'descriere': 'Pl-x 596/2005',
#  'time': '06.02.2006 17:13',
#  'camera': '2',
#  'type': 'PL',
#  'lung': 'Proiect de Lege pentru ratificarea Acordului între România şi Confederaţia Elveţiană privind cooperarea în combaterea terorismului, criminalităţii organizate, a traficului ilicit de stupefiante, substanţe psihotrope şi precursori, precum şi a altor infracţiuni transnaţionale, semnat la Bucureşti la 19 septembrie 2005',
#  'lege': '596/2005',
#  'link': 'http://www.cdep.ro/pls/proiecte/upl_pck2015.proiect?cam=2&idp=6897'}

# %%
dr=pd.DataFrame(records)
dr['votid']=dr['votid'].astype(int)

# %%
dv=pd.DataFrame(nvotes)[['time','votid','lung','type','lege']]
dv['votid']=dv['votid'].astype(int)

# %%
df.head()
# Out:
#      votid camera       grup                  name vot              time  \
# 893    316      2       PD-L      Mocanu Alexandru  DA  06.02.2006 16:59
# 894    316      2  neafiliat       Ovidenie Costel  DA  06.02.2006 16:59
# 895    316      2        PNL     Calimente Mihăiţă  DA  06.02.2006 16:59
# 896    316      2        PNL         Oancea Viorel  DA  06.02.2006 16:59
# 897    316      2       PD-L  Bardan Cornel Ştefan  DA  06.02.2006 16:59
#
#                                                   lung type      lege  \
# 893  Proiect de Lege pentru abrogarea unor preveder...   PL  621/2005
# 894  Proiect de Lege pentru abrogarea unor preveder...   PL  621/2005
# 895  Proiect de Lege pentru abrogarea unor preveder...   PL  621/2005
# 896  Proiect de Lege pentru abrogarea unor preveder...   PL  621/2005
# 897  Proiect de Lege pentru abrogarea unor preveder...   PL  621/2005
#
#          years
# 893 2006-02-06
# 894 2006-02-06
# 895 2006-02-06
# 896 2006-02-06
# 897 2006-02-06

# %%
dv.head()
# Out:
#                time  votid                                               lung  \
# 0  06.02.2006 17:13    318  Proiect de Lege pentru ratificarea Acordului î...
# 1  06.02.2006 17:22    320  Proiect de Lege pentru ratificarea Acordului î...
# 2  06.02.2006 17:29    321                                Retrimitere comisie
# 3  06.02.2006 17:31    322                                Retrimitere comisie
# 4  06.02.2006 16:56    315                                    Timpi dezbatere
#
#     type      lege
# 0     PL  596/2005
# 1     PL  640/2005
# 2  Other
# 3  Other
# 4  Other

# %%
dvset=set(dv['votid'].unique())

# %%
drset=set(dr['votid'].unique())

# %%
drset.difference(dvset)
# Out:
# set()

# %%
dvset.difference(drset)
# Out:
# {3686, 5896, 9915, 16556}

# %%
df0=dr.set_index('votid').join(dv.set_index('votid')).reset_index()

# %%
df1=df0.groupby('camera').nunique()[['votid','name']]
df2=df0.groupby('camera').count()[['votid','name']]

# %%
szen=['Szenátus','Képviselőház']
szen2=['Senat','Camera Deputaților']

# %%
df3=df2/df1
df3['Szavazások száma']=df1['votid']
df3['Szavazatok száma']=df2['votid']
df3['Átlagosan szavazott']=np.round(df3['votid']).astype(int)
df3['Összesen']=[136,329]
df3['Szavazati arány (%)']=df3['Átlagosan szavazott']*100/df3['Összesen']
df3['Szavazati arány (%)']=np.round(df3['Szavazati arány (%)']).astype(int)
df3.index.name=''
df3.index=szen

# %%
df3[['Szavazások száma','Szavazatok száma','Átlagosan szavazott','Összesen','Szavazati arány (%)']]
# Out:
#               Szavazások száma  Szavazatok száma  Átlagosan szavazott  \
# Szenátus                   761             59524                   78
# Képviselőház             16013           3322632                  207
#
#               Összesen  Szavazati arány (%)
# Szenátus           136                   57
# Képviselőház       329                   63

# %%
years=[]
for i in df0['time'].values:
    t=i[-10:-6]+'-'+i[-13:-11]+'-'+i[-16:-14]
    years.append(t)
df0['years']=pd.to_datetime(years)

# %% [markdown]
# Numai proiecte de legi

# %%
df=df0[df0['type']=='PL']

# %%
df1=df.groupby('camera').nunique()[['votid','name']]
df2=df.groupby('camera').count()[['votid','name']]

# %%
df3=df2/df1
df3['Szavazások száma']=df1['votid']
df3['Szavazatok száma']=df2['votid']
df3['Átlagosan szavazott']=np.round(df3['votid']).astype(int)
df3['Összesen']=[136,329]
df3['Szavazati arány (%)']=df3['Átlagosan szavazott']*100/df3['Összesen']
df3['Szavazati arány (%)']=np.round(df3['Szavazati arány (%)']).astype(int)
df3.index.name=''
df3.index=['Szenátus','Képviselőház']

# %%
df3[['Szavazások száma','Szavazatok száma','Átlagosan szavazott','Összesen','Szavazati arány (%)']]
# Out:
#               Szavazások száma  Szavazatok száma  Átlagosan szavazott  \
# Szenátus                    31              3368                  109
# Képviselőház              9848           2232757                  227
#
#               Összesen  Szavazati arány (%)
# Szenátus           136                   80
# Képviselőház       329                   69

# %% [markdown]
# Word clouds

# %%
dl=dv[dv['type']=='PL'].drop_duplicates(subset='lege',keep='first')

# %%
years=[]
for i in dl['time'].values:
    t=i[-10:-6]+'-'+i[-13:-11]+'-'+i[-16:-14]
    years.append(t)
dl['years']=pd.to_datetime(years)

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sw={'PL','PLX','vot','final','Vot','adoptare','Anexa','Amr','Art','respingere','respins','comisie','Proiectul',
   'amendament','Hotarare','Retrimitere','la','de zi','nr','de','Lege','Proiect','pentru','modificarea'}

# %%
sw2={'Propunere','legistativă','completarea','Ordonanței','urgenţă','aprobarea Ordonanţei','aprobarea',
    'privind','Guvernului','precum','şi','Ordonanţei  urgenţă','Ordonanţei','Ordonanţa','Legii','legislativă',
    'organizarea','funcţionarea','unor','unele','măsuri','legislativă','legistivă','domeniul','Acordului','al',
    'din','ratificarea','cu','completate','modificările','între','semnat','Guvernul','Republicii','ulterioare',
     'completările','stabilirea','vederea','Legea','acte','normative','Codul','republicată','alin','Monitorul','în',
    'României','publice','administraţiei','care','au','sau'}

# %%
sw3={'Oficial','modificare','lit','publicată'
 'Partea','vor',
 'România','Române','Român','declararea',
 'abrogarea','altor','acestora',
 'alte','august','aflate','unui',
 'aprilie','septembrie','Partea',
 'decembrie','naţional','programului',
 'drepturi','Naţional','Naţională',
 'fiscal','articolului','Naţionale',
 'ianuarie','martie','Republica',
 'iulie','adoptat','regimul',
 'iunie','cadrul','statului',
 'noiembrie','stat','pe','ca',
 'octombrie','mai','ale','ce se','dintre','acestora',
 'prin','Convenţiei','către',
 'reglementarea','urgenţã','acordarea','acordare','anul','privire','FIECARE',
 'respingerea',
 'înfiinţarea'}

# %%
sw4={'Bucureşti'}

# %%
w=15
h=10
for year in range(2006,2020):
    dy=dl[dl['years']>pd.to_datetime(str(year))]
    dy=dy[dy['years']<pd.to_datetime(str(year+1))]
    desc=', '.join(dy['lung'].unique())
    wordcloud = WordCloud(relative_scaling = 0.1, background_color="white",width=w*60,height=h*60,
                          collocations=True,    
                          stopwords = set(STOPWORDS.union(sw).union(sw2).union(sw3).union(sw4))
                              ).generate(desc)
    plt.figure(figsize=(w,h))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.title('Temele voturilor in Parlamentul României în anul '+str(year),y=1.04,fontsize=20)
    plt.savefig(str(year)+'.png')
    plt.close()
    print(year)
# Out:
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019

# %%
dy=dl
desc=', '.join(dy['lung'].unique())
wordcloud = WordCloud(relative_scaling = 0.1, background_color="white",width=w*60,height=h*60,
                      collocations=True,    
                      stopwords = set(STOPWORDS.union(sw).union(sw2).union(sw3).union(sw4))
                          ).generate(desc)
plt.figure(figsize=(w,h))
plt.imshow(wordcloud)
plt.axis("off")
plt.title('Temele voturilor in Parlamentul României în anurile 2006-2019',y=1.04,fontsize=20)
plt.savefig('all.png')
plt.close()

# %%
legs={'2016':['2016-12-21','2019-05-01'],
'2012':['2012-12-20','2016-12-21'],
'2008':['2008-12-19','2012-12-20'],
'2004':['2004-12-19','2008-12-13'],
'2000':['2000-12-15','2004-11-30'],
'1996':['1996-11-27','2000-11-30'],
'1992':['1992-10-28','1996-11-22'],
'1990':['1990-06-19','1992-10-16']}

# %%
for year in legs:
    dy=dl[dl['years']>pd.to_datetime(legs[year][0])]
    dy=dy[dy['years']<pd.to_datetime(legs[year][1])]
    if len(dy):
        desc=', '.join(dy['lung'].unique())
        wordcloud = WordCloud(relative_scaling = 0.1, background_color="white",width=w*60,height=h*60,
                              collocations=True,    
                              stopwords = set(STOPWORDS.union(sw).union(sw2).union(sw3).union(sw4))
                                  ).generate(desc)
        plt.figure(figsize=(w,h))
        plt.imshow(wordcloud)
        plt.axis("off")
        plt.title('Temele voturilor in Parlamentul României în Legislatura '+str(year),y=1.04,fontsize=20)
        plt.savefig('Leg-'+str(year)+'.png')
        plt.close()
        print(year)
# Out:
# 2016
# 2012
# 2008
# 2004

# %% [markdown]
# Voting ratios

# %%
df0
# Out:
#          votid camera        grup                        name vot  \
# 0          311      2        PD-L            Mocanu Alexandru  DA
# 1          311      2   neafiliat             Ovidenie Costel  DA
# 2          311      2         PNL           Calimente Mihăiţă  DA
# 3          311      2         PNL               Oancea Viorel  DA
# 4          311      2         PNL          Bărbuleţiu Tiberiu  DA
# 5          311      2         PNL           Dragomir Gheorghe  DA
# 6          311      2   neafiliat           Guşă Cozmin Horea   -
# 7          311      2   neafiliat          Pavelescu Aurelian  DA
# 8          311      2   neafiliat      Şandru Marcela Lavinia  DA
# 9          311      2        PD-L            Zegrean Augustin  DA
# 10         311      2         PRM       Dumitriu Dragoş Petre  DA
# 11         311      2         PSD               Nechita Aurel  DA
# 12         311      2          PC                Ţundrea Ioan  DA
# 13         311      2         PSD                  Timiş Ioan  DA
# 14         311      2   neafiliat             Ciontu Corneliu  DA
# 15         311      2         PNL                Dobre Traian  DA
# 16         311      2         PSD               Vlădoiu Aurel  DA
# 17         311      2        PD-L      Igaş Traian Constantin  DA
# 18         311      2         PSD               Sârb Gheorghe  AB
# 19         311      2         PSD               Pupeză Viorel  DA
# 20         311      2         PSD                Tudose Mihai  DA
# 21         311      2         PSD              Gubandru Aurel  DA
# 22         311      2          PC            Tudor Constantin  DA
# 23         311      2        UDMR         Máté András-Levente  DA
# 24         311      2         PNL       Iustian Mircea Teodor  DA
# 25         311      2        PD-L                Movilă Petru  DA
# 26         311      2         PSD              Mitrea Manuela  DA
# 27         311      2         PNL           Ursărescu Dorinel  DA
# 28         311      2         PSD        Nicula Vasile Cosmin  DA
# 29         311      2         PSD           Ştireanu Octavian  DA
# ...        ...    ...         ...                         ...  ..
# 3382126  22365      2         PMP     Turcescu Robert-Nicolae  NU
# 3382127  22365      2         PSD          Tuşa Adriana Diana  DA
# 3382128  22365      2         USR   Ungureanu Emanuel-Dumitru  NU
# 3382129  22365      2         PNL            Varga Glad-Aurel  NU
# 3382130  22365      2         PNL                Varga Vasile  NU
# 3382131  22365      2  Minoritati               Vasile Daniel  DA
# 3382132  22365      2         PSD        Vasilescu Lia Olguţa  DA
# 3382133  22365      2         PSD        Vasilică Radu Costin  DA
# 3382134  22365      2         PSD              Velcea Nicolae  DA
# 3382135  22365      2         PSD        Vişan George-Gabriel  DA
# 3382136  22365      2         PSD               Vîrză Mihăiţă  DA
# 3382137  22365      2         USR          Vlad Sergiu Cosmin  NU
# 3382138  22365      2         PNL       Voicu Mihai Alexandru  NU
# 3382139  22365      2         PSD                 Weber Mihai  DA
# 3382140  22365      2         USR               Zainea Cornel  NU
# 3382141  22365      2         PSD  Zamfira Constantin-Cătălin  DA
# 3382142  22365      2         PNL             Trăilă Cristina  NU
# 3382143  22365      2         PSD               Răduţ Violeta  DA
# 3382144  22365      2         USR      Popescu Nicolae-Daniel  NU
# 3382145  22365      2         PSD             Gherman Dumitru  DA
# 3382146  22365      2         PSD    Vrăjitoru Sorinel-Marian  DA
# 3382147  22365      2         PSD               Gilia Claudia  DA
# 3382148  22365      2         PSD                  Teiş Alina  DA
# 3382149  22365      2         PSD               Cosma Andreea  DA
# 3382150  22365      2         PSD             Ursu Răzvan-Ion  DA
# 3382151  22365      2         PSD                 Suciu Matei  DA
# 3382152  22365      2         PSD               Radu Anişoara  DA
# 3382153  22365      2         PSD               Hărătău Elena  DA
# 3382154  22365      2  Minoritati             Ampleev Andrian  DA
# 3382155  22365      2         PSD                 Stan Viorel  DA
#
#                      time                                               lung  \
# 0        06.02.2006 16:36                                 Componenta comisii
# 1        06.02.2006 16:36                                 Componenta comisii
# 2        06.02.2006 16:36                                 Componenta comisii
# 3        06.02.2006 16:36                                 Componenta comisii
# 4        06.02.2006 16:36                                 Componenta comisii
# 5        06.02.2006 16:36                                 Componenta comisii
# 6        06.02.2006 16:36                                 Componenta comisii
# 7        06.02.2006 16:36                                 Componenta comisii
# 8        06.02.2006 16:36                                 Componenta comisii
# 9        06.02.2006 16:36                                 Componenta comisii
# 10       06.02.2006 16:36                                 Componenta comisii
# 11       06.02.2006 16:36                                 Componenta comisii
# 12       06.02.2006 16:36                                 Componenta comisii
# 13       06.02.2006 16:36                                 Componenta comisii
# 14       06.02.2006 16:36                                 Componenta comisii
# 15       06.02.2006 16:36                                 Componenta comisii
# 16       06.02.2006 16:36                                 Componenta comisii
# 17       06.02.2006 16:36                                 Componenta comisii
# 18       06.02.2006 16:36                                 Componenta comisii
# 19       06.02.2006 16:36                                 Componenta comisii
# 20       06.02.2006 16:36                                 Componenta comisii
# 21       06.02.2006 16:36                                 Componenta comisii
# 22       06.02.2006 16:36                                 Componenta comisii
# 23       06.02.2006 16:36                                 Componenta comisii
# 24       06.02.2006 16:36                                 Componenta comisii
# 25       06.02.2006 16:36                                 Componenta comisii
# 26       06.02.2006 16:36                                 Componenta comisii
# 27       06.02.2006 16:36                                 Componenta comisii
# 28       06.02.2006 16:36                                 Componenta comisii
# 29       06.02.2006 16:36                                 Componenta comisii
# ...                   ...                                                ...
# 3382126  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382127  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382128  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382129  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382130  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382131  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382132  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382133  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382134  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382135  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382136  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382137  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382138  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382139  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382140  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382141  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382142  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382143  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382144  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382145  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382146  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382147  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382148  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382149  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382150  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382151  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382152  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382153  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382154  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
# 3382155  24.04.2019 12:21  Proiect de Lege privind aprobarea Ordonanţei d...
#
#           type      lege
# 0        Other
# 1        Other
# 2        Other
# 3        Other
# 4        Other
# 5        Other
# 6        Other
# 7        Other
# 8        Other
# 9        Other
# 10       Other
# 11       Other
# 12       Other
# 13       Other
# 14       Other
# 15       Other
# 16       Other
# 17       Other
# 18       Other
# 19       Other
# 20       Other
# 21       Other
# 22       Other
# 23       Other
# 24       Other
# 25       Other
# 26       Other
# 27       Other
# 28       Other
# 29       Other
# ...        ...       ...
# 3382126     PL  406/1997
# 3382127     PL  406/1997
# 3382128     PL  406/1997
# 3382129     PL  406/1997
# 3382130     PL  406/1997
# 3382131     PL  406/1997
# 3382132     PL  406/1997
# 3382133     PL  406/1997
# 3382134     PL  406/1997
# 3382135     PL  406/1997
# 3382136     PL  406/1997
# 3382137     PL  406/1997
# 3382138     PL  406/1997
# 3382139     PL  406/1997
# 3382140     PL  406/1997
# 3382141     PL  406/1997
# 3382142     PL  406/1997
# 3382143     PL  406/1997
# 3382144     PL  406/1997
# 3382145     PL  406/1997
# 3382146     PL  406/1997
# 3382147     PL  406/1997
# 3382148     PL  406/1997
# 3382149     PL  406/1997
# 3382150     PL  406/1997
# 3382151     PL  406/1997
# 3382152     PL  406/1997
# 3382153     PL  406/1997
# 3382154     PL  406/1997
# 3382155     PL  406/1997
#
# [3382156 rows x 9 columns]

# %%
df=df0[df0['type']=='PL']

# %%
dfs1=[]
for year in range(2006,2020):
    dy=df[df['years']>pd.to_datetime(str(year))]
    dy=dy[dy['years']<pd.to_datetime(str(year+1))]
    if len(dy):
        df1=dy.groupby('camera').nunique()[['votid','name']]
        df2=dy.groupby('camera').count()[['votid','name']]
        df3=df2/df1
        df3['Szavazások száma']=df1['votid']
        df3['Szavazatok száma']=df2['votid']
        df3['Átlagosan szavazott']=np.round(df3['votid']).astype(int)
        if len(df3)==2:
            df3['Összesen']=[136,329]
            df3.index=['Szenátus','Képviselőház']
        else:
            df3['Összesen']=[329]
            df3.index=['Képviselőház']
        df3['Szavazati arány (%)']=df3['Átlagosan szavazott']*100/df3['Összesen']
        df3['Szavazati arány (%)']=np.round(df3['Szavazati arány (%)']).astype(int)
        df3.index.name=''
        #df3[['Szavazások száma','Szavazatok száma','Átlagosan szavazott','Összesen','Szavazati arány (%)']].to_excel(str(year)+'.xlsx')
        df3['Év']=year
        dfs1.append(df3)
        print(year)
# Out:
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019

# %%
dfs2=[]
for year in legs:
    dy=df[df['years']>pd.to_datetime(legs[year][0])]
    dy=dy[dy['years']<pd.to_datetime(legs[year][1])]
    if len(dy):
        df1=dy.groupby('camera').nunique()[['votid','name']]
        df2=dy.groupby('camera').count()[['votid','name']]
        df3=df2/df1
        df3['Szavazások száma']=df1['votid']
        df3['Szavazatok száma']=df2['votid']
        df3['Átlagosan szavazott']=np.round(df3['votid']).astype(int)
        if len(df3)==2:
            df3['Összesen']=[136,329]
            df3.index=['Szenátus','Képviselőház'] 
        else:
            df3['Összesen']=[329]
            df3.index=['Képviselőház']
        df3['Szavazati arány (%)']=df3['Átlagosan szavazott']*100/df3['Összesen']
        df3['Szavazati arány (%)']=np.round(df3['Szavazati arány (%)']).astype(int)
        df3.index.name=''
        #df3[['Szavazások száma','Szavazatok száma','Átlagosan szavazott','Összesen','Szavazati arány (%)']].to_excel('Leg-'+str(year)+'.xlsx')
        df3['Törvényhozás']=year
        dfs2.append(df3)
        print(year)
# Out:
# 2016
# 2012
# 2008
# 2004

# %%
dfs1=pd.concat(dfs1)
dfs2=pd.concat(dfs2)

# %%
df=df0.copy()

# %%
dfs3=[]
for year in range(2006,2020):
    dy=df[df['years']>pd.to_datetime(str(year))]
    dy=dy[dy['years']<pd.to_datetime(str(year+1))]
    if len(dy):
        df1=dy.groupby('camera').nunique()[['votid','name']]
        df2=dy.groupby('camera').count()[['votid','name']]
        df3=df2/df1
        df3['Szavazások száma']=df1['votid']
        df3['Szavazatok száma']=df2['votid']
        df3['Átlagosan szavazott']=np.round(df3['votid']).astype(int)
        if len(df3)==2:
            df3['Összesen']=[136,329]
            df3.index=['Szenátus','Képviselőház']
        else:
            df3['Összesen']=[329]
            df3.index=['Képviselőház']
        df3['Szavazati arány (%)']=df3['Átlagosan szavazott']*100/df3['Összesen']
        df3['Szavazati arány (%)']=np.round(df3['Szavazati arány (%)']).astype(int)
        df3.index.name=''
        #df3[['Szavazások száma','Szavazatok száma','Átlagosan szavazott','Összesen','Szavazati arány (%)']].to_excel(str(year)+'.xlsx')
        df3['Év']=year
        dfs3.append(df3)
        print(year)
# Out:
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019

# %%
dfs4=[]
for year in legs:
    dy=df[df['years']>pd.to_datetime(legs[year][0])]
    dy=dy[dy['years']<pd.to_datetime(legs[year][1])]
    if len(dy):
        df1=dy.groupby('camera').nunique()[['votid']]
        df2=dy.groupby('camera').count()[['votid']]
        df3=df2/df1
        df3['Szavazások száma']=df1['votid']
        df3['Szavazatok száma']=df2['votid']
        df3['Átlagosan szavazott']=np.round(df3['votid']).astype(int)
        if len(df3)==2:
            df3['Összesen']=[136,329]
        else:
            df3['Összesen']=[329]
        df3['Szavazati arány (%)']=df3['Átlagosan szavazott']*100/df3['Összesen']
        df3['Szavazati arány (%)']=np.round(df3['Szavazati arány (%)']).astype(int)
        #df3[['Szavazások száma','Szavazatok száma','Átlagosan szavazott','Összesen','Szavazati arány (%)']].to_excel('Leg-'+str(year)+'.xlsx')
        df3['Törvényhozás']=year
        dfs4.append(df3)
        print(year)
# Out:
# 2016
# 2012
# 2008
# 2004

# %%
#dfs3=pd.concat(dfs3)
dfs4=pd.concat(dfs4)

# %% [markdown]
# Kepviselok

# %%
dfs6=[]
for year in legs:
    dy=df[df['years']>pd.to_datetime(legs[year][0])]
    dy=dy[dy['years']<pd.to_datetime(legs[year][1])]
    if len(dy):
        df2=dy.groupby(['camera','name']).count()[['votid']]
        df2.columns=['Szavazott']
        #df3[['Szavazások száma','Szavazatok száma','Átlagosan szavazott','Összesen','Szavazati arány (%)']].to_excel('Leg-'+str(year)+'.xlsx')
        df2['Törvényhozás']=year
        dfs6.append(df2)
        print(year)
# Out:
# 2016
# 2012
# 2008
# 2004

# %%
dfs6=pd.concat(dfs6)

# %%
dfs6=dfs6.reset_index().set_index(['camera','Törvényhozás']).join(dfs4.set_index('Törvényhozás',append=True))

# %%
dfs6['Részvétel']=np.round(dfs6['Szavazott']*100/dfs6['Szavazások száma']).astype(int)

# %%
dfs6.head()
# Out:
#                                         name  Szavazott      votid  \
# camera Törvényhozás
# 1      2016          Alexandrescu Vlad-Tudor        307  78.218134
#        2016             Andronescu Ecaterina        246  78.218134
#        2016              Antal István-Loránt        495  78.218134
#        2016                     Arcan Emilia        649  78.218134
#        2016                     Arcaş Viorel        358  78.218134
#
#                      Szavazások száma  Szavazatok száma  Átlagosan szavazott  \
# camera Törvényhozás
# 1      2016                       761             59524                   78
#        2016                       761             59524                   78
#        2016                       761             59524                   78
#        2016                       761             59524                   78
#        2016                       761             59524                   78
#
#                      Összesen  Szavazati arány (%)  Részvétel
# camera Törvényhozás
# 1      2016               136                   57         40
#        2016               136                   57         32
#        2016               136                   57         65
#        2016               136                   57         85
#        2016               136                   57         47

# %%
df1=df.groupby(['type','camera','years']).nunique()[['votid']]
df2=df.groupby(['type','camera','years']).count()[['votid']]
df3=df2/df1
df3['Szavazások száma']=df1['votid']
df3['Szavazatok száma']=df2['votid']
df3['Átlagosan szavazott']=np.round(df3['votid']).astype(int)

# %%
du=df3.loc['PL'].loc['2']
du['Részvételi arány (%)']=np.round(du['Átlagosan szavazott']/3.29)
du['Részvételi arány (%)'].hist(bins=20)
du['Részvételi arány (%)'].plot()
du=df3.loc['Other'].loc['2']
du['Részvételi arány (%)']=np.round(du['Átlagosan szavazott']/3.29)
du['Részvételi arány (%)'].hist(bins=20)
du['Részvételi arány (%)'].plot()

# %%
du=df3.loc['PL'].loc['1']
du['Részvételi arány (%)']=np.round(du['Átlagosan szavazott']/1.36)
du['Részvételi arány (%)'].hist(bins=20)
du['Részvételi arány (%)'].plot()
du=df3.loc['Other'].loc['1']
du['Részvételi arány (%)']=np.round(du['Átlagosan szavazott']/1.36)
du['Részvételi arány (%)'].hist(bins=20)
du['Részvételi arány (%)'].plot()

# %%
import altair as alt

# %%
df1=df.groupby(['type','camera','years','grup']).nunique()[['votid']]
df2=df.groupby(['type','camera','years','grup']).count()[['votid']]
df3=df2/df1
df3['Szavazások száma']=df1['votid']
df3['Szavazatok száma']=df2['votid']
df3['Átlagosan szavazott']=np.round(df3['votid']).astype(int)

# %%
du=df3.loc['PL'].loc['2']
du=du['Átlagosan szavazott'].reset_index()
du.columns=['Szavazás időpontja','Párt','Szavazatok']

# %%
du=du.set_index(['Párt','Szavazás időpontja']).sort_values(by=['Párt','Szavazás időpontja']).rolling(9).mean().reset_index()
du['Dátum']=du['Szavazás időpontja'].astype(str)

# %%
du=du.dropna()
du['Szavazatok']=np.round(du['Szavazatok']).astype(int)

# %%
dua=du.groupby(['Szavazás időpontja']).sum()
dua.columns=['Összesen']
du=du.set_index('Szavazás időpontja').join(dua).reset_index()
du['Eloszlás (%)']=np.round(du['Szavazatok']*100/du['Összesen'])

# %%
du=du.replace('Mino.','Minorități').replace('Minoritati','Minorități').replace('Prog.','Independent')\
    .replace('neafiliat','Independent').replace('PD-L','PDL').replace('ND','PP-DD')

# %%
parties=du['Párt']
for p in img['party']:
    parties=parties.replace(p, img['party'][p]['name'])
du['Párt név']=parties

# %%
from colorthief import ColorThief
import requests

# %%
party_imgs={}
for p in img['party']:
    i=img['party'][p]['img']
    if i:
        color_thief = ColorThief('img2/'+p.lower()+'.png')
        rgb_color=color_thief.get_color(quality=1)        
        z='#%02x%02x%02x' % rgb_color
    else:
        try:
            color_thief = ColorThief('img/'+p.lower()+'.png')
            rgb_color=color_thief.get_color(quality=1)        
            z='#%02x%02x%02x' % rgb_color
        except:
            z='grey'
    
    party_imgs[p]=z

# %%
party_imgs['UDMR']='green'
party_imgs['PNL']='#f4d42c'
party_imgs['ALDE']='#046cab'

# %%
colors=pd.DataFrame(party_imgs,index=['Color']).T

# %%
order=list(du.groupby('Párt').sum()['Szavazatok'].sort_values().index)[::-1]
colors=pd.DataFrame(party_imgs,index=['Color']).T.loc[order]
colors['Order']=[i for i in range(len(colors))]

# %%
du=du.join(colors,on='Párt')

# %%
cl=du[['Párt','Color']].drop_duplicates()
cl=cl.set_index('Párt').loc[order[::-1]].reset_index()
do=[img['party'][i]['name'] for i in list(cl['Párt'])]
ra=list(cl['Color'])

# %%
alt.Chart(du).mark_bar().encode(
    x="Szavazás időpontja:T",
    y=alt.Y("Eloszlás (%):Q",stack='normalize'),
    color=alt.Color("Párt név:N",scale=alt.Scale(domain=do,range=ra)),
    order=alt.Order("Order"),
    tooltip=['Dátum', 'Párt', 'Szavazatok','Eloszlás (%)']
)#.interactive()
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(du).mark_line().encode(
    x="Szavazás időpontja:T",
    y=alt.Y("Eloszlás (%):Q"),
    color=alt.Color("Párt név:N",scale=alt.Scale(domain=do,range=ra)),
    tooltip=['Dátum', 'Párt', 'Szavazatok','Eloszlás (%)']
)#.interactive()
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
race=du.drop_duplicates(subset=['Szavazás időpontja','Párt'],keep='first').set_index(['Szavazás időpontja','Párt']).unstack()['Eloszlás (%)']

# %%
race=race.resample('1M').mean()
race.index=[i.month_name(locale='hu')+' '+str(i.year) for i in race.index]
race.T.to_excel('raceM.xlsx')

# %%
race=du.drop_duplicates(subset=['Szavazás időpontja','Párt'],keep='first').set_index(['Szavazás időpontja','Párt']).unstack()['Eloszlás (%)']

# %%
race=race.resample('1Y').mean()
race.index=[str(i.year) for i in race.index]
race=race.T

# %%
plinks={}
for i in colors.index:
    print(i+':'+colors.loc[i]['Color'])
    plinks[i]='https://influence.csaladen.es/ro/img/'+i.lower()+'.png'
# Out:
# PSD:#db231b
# PNL:#f4d42c
# PDL:#f74c06
# UDMR:green
# Minorități:grey
# Independent:#eeeeee
# USR:#04abe4
# ALDE:#046cab
# PP-DD:#d7c9e0
# PRM:#d1b80e
# PMP:#0484cc
# PC:#96c2f2
# UNPR:#4b386d

# %%
pd.DataFrame(plinks,index=['link']).T.join(race).to_excel('raceY.xlsx')

# %% [markdown]
# Members

# %%
istart=legs['1990'][0]
iend='2019-05-01'

# %%
m=nmembers['Popescu-Tariceanu Calin Constantin Anton']
data=[]
for p in m['Parties']:
    start=pd.to_datetime(p['start'])
    end=pd.to_datetime(p['end'])    
    d={}
    d['Name']=m['Name']['full']
    d['Csoportok']=p['party']
    d['Típus']='Párt'
    d['start']=start
    d['end']=end
    d['duration']=pd.to_timedelta(end-start).days
    data.append(d)
    d=dict(d)
    d['Csoportok']=p['judet']
    d['Típus']='Megye'
    data.append(d)
for p in m['Countries']:
    start=pd.to_datetime(p['start'])
    end=pd.to_datetime(p['end'])    
    d={}
    d['Name']=m['Name']['full']
    d['Csoportok']=p['country']
    d['Típus']='Ország'
    d['start']=start
    d['end']=end
    d['duration']=pd.to_timedelta(end-start).days
    data.append(d)
for p in m['Groups']:
    start=pd.to_datetime(p['start'])
    end=pd.to_datetime(p['end'])    
    d={}
    d['Name']=m['Name']['full']
    d['Csoportok']=p['group'].replace('Comisia pentru','').replace('Comisia','').strip().capitalize()
    d['Típus']='Bizottság'
    d['start']=start
    d['end']=end
    d['duration']=pd.to_timedelta(end-start).days
    data.append(d)
for p in m['Link']:
    start=pd.to_datetime(legs[p[-10:-6]][0])
    end=pd.to_datetime(legs[p[-10:-6]][1])    
    d={}
    d['Name']=m['Name']['full']
    d['Csoportok']=szen2[int(p[-1])-1]
    d['Típus']='Kamara'
    d['start']=start
    d['end']=end
    d['duration']=pd.to_timedelta(end-start).days
    data.append(d)
ef=pd.DataFrame(data)
eord=ef.groupby('Típus').sum()
eord['duration']=[1,60,30,4,50]
eord.columns=['order']
ef=ef.set_index('Típus').join(eord).reset_index()

# %%
alt.Chart(ef,
          title=m['Name']['full']
         ).mark_bar().encode(
    x=alt.X('start:T',title=''),
    x2='end:T',
    y=alt.Y('Csoportok:N',title='',
            sort=alt.EncodingSortField(field="order", op="mean", order='descending')),
    color=alt.Color('Típus:N',
        sort=alt.EncodingSortField(field="order", op="mean", order='descending'))
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
m=nmembers['Kelemen Hunor']
data=[]
for p in m['Parties']:
    start=pd.to_datetime(p['start'])
    end=pd.to_datetime(p['end'])    
    d={}
    d['Name']=m['Name']['full']
    d['Csoportok']=p['party']
    d['Típus']='Párt'
    d['start']=start
    d['end']=end
    d['duration']=pd.to_timedelta(end-start).days
    data.append(d)
    d=dict(d)
    d['Csoportok']=p['judet']
    d['Típus']='Megye'
    data.append(d)
for p in m['Countries']:
    start=pd.to_datetime(p['start'])
    end=pd.to_datetime(p['end'])    
    d={}
    d['Name']=m['Name']['full']
    d['Csoportok']=p['country']
    d['Típus']='Ország'
    d['start']=start
    d['end']=end
    d['duration']=pd.to_timedelta(end-start).days
    data.append(d)
for p in m['Groups']:
    start=pd.to_datetime(p['start'])
    end=pd.to_datetime(p['end'])    
    d={}
    d['Name']=m['Name']['full']
    d['Csoportok']=p['group'].replace('Comisia pentru','').replace('Comisia','').strip().capitalize()
    d['Típus']='Bizottság'
    d['start']=start
    d['end']=end
    d['duration']=pd.to_timedelta(end-start).days
    data.append(d)
for p in m['Link']:
    start=pd.to_datetime(legs[p[-10:-6]][0])
    end=pd.to_datetime(legs[p[-10:-6]][1])    
    d={}
    d['Name']=m['Name']['full']
    d['Csoportok']=szen2[int(p[-1])-1]
    d['Típus']='Kamara'
    d['start']=start
    d['end']=end
    d['duration']=pd.to_timedelta(end-start).days
    data.append(d)
ef=pd.DataFrame(data)
eord=ef.groupby('Típus').sum()
eord['duration']=[1,60,30,4,50]
eord.columns=['order']
ef=ef.set_index('Típus').join(eord).reset_index()

# %%
alt.Chart(ef,
          title=m['Name']['full']
         ).mark_bar().encode(
    x=alt.X('start:T',title=''),
    x2='end:T',
    y=alt.Y('Csoportok:N',title='',
            sort=alt.EncodingSortField(field="order", op="mean", order='descending')),
    color=alt.Color('Típus:N',
        sort=alt.EncodingSortField(field="order", op="mean", order='descending'))
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
m=nmembers['Dragnea Nicolae-Liviu']
data=[]
for p in m['Parties']:
    start=pd.to_datetime(p['start'])
    end=pd.to_datetime(p['end'])    
    d={}
    d['Name']=m['Name']['full']
    d['Csoportok']=p['party']
    d['Típus']='Párt'
    d['start']=start
    d['end']=end
    d['duration']=pd.to_timedelta(end-start).days
    data.append(d)
    d=dict(d)
    d['Csoportok']=p['judet']
    d['Típus']='Megye'
    data.append(d)
for p in m['Countries']:
    start=pd.to_datetime(p['start'])
    end=pd.to_datetime(p['end'])    
    d={}
    d['Name']=m['Name']['full']
    d['Csoportok']=p['country']
    d['Típus']='Ország'
    d['start']=start
    d['end']=end
    d['duration']=pd.to_timedelta(end-start).days
    data.append(d)
for p in m['Groups']:
    start=pd.to_datetime(p['start'])
    end=pd.to_datetime(p['end'])    
    d={}
    d['Name']=m['Name']['full']
    d['Csoportok']=p['group'].replace('Comisia pentru','').replace('Comisia','').strip().capitalize()
    d['Típus']='Bizottság'
    d['start']=start
    d['end']=end
    d['duration']=pd.to_timedelta(end-start).days
    data.append(d)
for p in m['Link']:
    start=pd.to_datetime(legs[p[-10:-6]][0])
    end=pd.to_datetime(legs[p[-10:-6]][1])    
    d={}
    d['Name']=m['Name']['full']
    d['Csoportok']=szen2[int(p[-1])-1]
    d['Típus']='Kamara'
    d['start']=start
    d['end']=end
    d['duration']=pd.to_timedelta(end-start).days
    data.append(d)
ef=pd.DataFrame(data)
eord=ef.groupby('Típus').sum()
eord['duration']=[1,60,30,4,50]
eord.columns=['order']
ef=ef.set_index('Típus').join(eord).reset_index()

# %%
alt.Chart(ef,
          title=m['Name']['full'].replace('DRAGNEA','DRAGNEA - ')
         ).mark_bar().encode(
    x=alt.X('start:T',title=''),
    x2='end:T',
    y=alt.Y('Csoportok:N',title='',
            sort=alt.EncodingSortField(field="order", op="mean", order='descending')),
    color=alt.Color('Típus:N',
        sort=alt.EncodingSortField(field="order", op="mean", order='descending'))
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
